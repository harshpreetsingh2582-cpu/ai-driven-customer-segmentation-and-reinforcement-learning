# %% [markdown]
# <a href="https://colab.research.google.com/github/harshpreetsingh2582-cpu/ai-driven-customer-segmentation-and-reinforcement-learning/blob/main/Unsupervised_and_Reinforcement_Learning_Practical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unsupervised Learning and Reinforcement Learning
#
# ## Google Colab Practical
#
# ### Learning Objectives
# By the end of this notebook, students will be able to:
#
# - Understand customer segmentation using K-Means Clustering.
# - Observe how similar customers are grouped together.
# - Interpret clusters from a business point of view.
# - Understand the basic idea of Reinforcement Learning.
# - Identify Agent, Action and Reward using a simple example.
#
# > **Note:** You are not expected to memorize the Python code. Focus on understanding what the output means for business decision-making.

# %% [markdown]
# # Part A: Customer Segmentation Using K-Means
#
# ## Business Problem
#
# An online retailer wants to understand different types of customers.
#
# The company has two simple pieces of information:
#
# - Monthly Spending
# - App Visits
#
# We will use K-Means Clustering to divide customers into **3 groups**.

# %% [markdown]
# ## Step 1: Import the Required Libraries
#
# We will use:
#
# - `pandas` to create and view the dataset
# - `KMeans` to create customer groups
# - `matplotlib` to visualize the clusters

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %% [markdown]
# ## Step 2: Create a Small Customer Dataset
#
# Each row represents one customer.

# %%
data = {
    "Customer": ["A", "B", "C", "D", "E", "F", "G", "H"],
    "Monthly_Spending": [9000, 8500, 1200, 1500, 5000, 5500, 8800, 1800],
    "App_Visits": [20, 18, 3, 4, 10, 12, 19, 5]
}

df = pd.DataFrame(data)

df

# %% [markdown]
# ### Observe the Data
#
# Think about these questions:
#
# 1. Which customers seem to spend the most?
# 2. Which customers visit the app most often?
# 3. Can you already notice any natural groups?

# %% [markdown]
# ## Step 3: Select the Features
#
# For clustering, we will use:
#
# - Monthly Spending
# - App Visits
#
# The customer name is only used as an identifier.

# %%
X = df[["Monthly_Spending", "App_Visits"]]

X

# %% [markdown]
# ## Step 4: Apply K-Means Clustering
#
# We will ask the model to create:
#
# **K = 3 clusters**

# %%
model = KMeans(n_clusters=3, random_state=42, n_init=10)

df["Cluster"] = model.fit_predict(X)

df

# %% [markdown]
# ## What Does the Cluster Column Mean?
#
# The model has placed customers into 3 groups.
#
# You may see cluster labels such as:
#
# - Cluster 0
# - Cluster 1
# - Cluster 2
#
# These numbers do **not** mean good, average or bad customers.
#
# They are simply group labels created by the model.

# %% [markdown]
# ## Step 5: Visualize the Customer Groups

# %%
plt.figure(figsize=(8, 5))

plt.scatter(
    df["Monthly_Spending"],
    df["App_Visits"],
    c=df["Cluster"],
    s=100
)

for i, customer in enumerate(df["Customer"]):
    plt.text(
        df["Monthly_Spending"][i] + 100,
        df["App_Visits"][i],
        customer
    )

plt.xlabel("Monthly Spending")
plt.ylabel("App Visits")
plt.title("Customer Segmentation Using K-Means")
plt.show()

# %% [markdown]
# ## Step 6: View Customers Cluster by Cluster

# %%
df.sort_values("Cluster")

# %% [markdown]
# ## Business Interpretation Activity
#
# Complete this table after observing the results:
#
# | Cluster | Customer Behaviour | Possible Business Name | Possible Business Action |
# |---|---|---|---|
# | Cluster 0 | | | |
# | Cluster 1 | | | |
# | Cluster 2 | | | |
#
# Possible business names may include:
#
# - Premium Customers
# - Medium-Value Customers
# - Low-Engagement Customers
#
# Possible actions may include:
#
# - Loyalty rewards
# - Personalized recommendations
# - Re-engagement campaign
#
# ### Important
# Do not decide the business name only from the cluster number.
#
# First observe:
#
# - Spending
# - App visits
# - Customer behaviour

# %% [markdown]
# ## Quick Questions
#
# 1. Which group has the highest spending?
# 2. Which group has the highest app activity?
# 3. Which group may need a re-engagement campaign?
# 4. Which group should receive loyalty benefits?
# 5. Why is customer segmentation useful for marketing?

# %% [markdown]
# # Part B: Introduction to Reinforcement Learning
#
# Reinforcement Learning is different from clustering.
#
# In Reinforcement Learning, a system learns by:
#
# **Taking an Action → Receiving a Reward → Learning from the Result**
#
# We will understand this using a very simple delivery-route example.

# %% [markdown]
# ## Business Scenario
#
# A delivery company has two possible routes:
#
# - Route A
# - Route B
#
# The company wants to choose the route that usually gives faster delivery.
#
# For simplicity:
#
# - Fast delivery gives a higher reward.
# - Slow delivery gives a lower reward.

# %% [markdown]
# ## Step 1: Define Some Example Rewards

# %%
route_rewards = {
    "Route A": [5, 4, 6, 5, 4],
    "Route B": [8, 9, 7, 10, 8]
}

route_rewards

# %% [markdown]
# ## Step 2: Calculate the Average Reward

# %%
for route, rewards in route_rewards.items():
    average_reward = sum(rewards) / len(rewards)
    print(route, "Average Reward =", average_reward)

# %% [markdown]
# ## Interpretation
#
# If Route B has a higher average reward, the system may prefer Route B more often.
#
# This represents the basic Reinforcement Learning idea:
#
# - **Agent:** Delivery decision system
# - **Environment:** Roads and traffic
# - **Action:** Choose Route A or Route B
# - **Reward:** Feedback based on delivery performance

# %% [markdown]
# ## Exploration vs Exploitation
#
# ### Exploration
# Try a new or less-used option.
#
# Example:
# Try Route A even if Route B usually performs better.
#
# ### Exploitation
# Use the option that is already known to perform well.
#
# Example:
# Choose Route B because it has previously given higher rewards.

# %% [markdown]
# ## Simple Exploration Example
#
# The following code randomly chooses a route.
#
# This represents **exploration**.

# %%
import random

choice = random.choice(["Route A", "Route B"])

print("Exploration choice:", choice)

# %% [markdown]
# ## Simple Exploitation Example
#
# The following code chooses the route with the higher average reward.
#
# This represents **exploitation**.

# %%
average_A = sum(route_rewards["Route A"]) / len(route_rewards["Route A"])
average_B = sum(route_rewards["Route B"]) / len(route_rewards["Route B"])

if average_A > average_B:
    print("Best known route: Route A")
else:
    print("Best known route: Route B")

# %% [markdown]
# # Final Comparison
#
# | Machine Learning Type | Main Idea | Business Example |
# |---|---|---|
# | Supervised Learning | Learn from known answers | Customer churn prediction |
# | Unsupervised Learning | Discover hidden patterns | Customer segmentation |
# | Reinforcement Learning | Learn from actions and rewards | Route optimization |

# %% [markdown]
# # Final Reflection
#
# Answer in 2–3 lines each:
#
# 1. What is Unsupervised Learning?
# 2. What is clustering?
# 3. What does K mean in K-Means?
# 4. How can customer segmentation help a business?
# 5. What is Reinforcement Learning?
# 6. What is an Agent?
# 7. What is an Action?
# 8. What is a Reward?
# 9. What is the difference between Exploration and Exploitation?
# 10. Which part of this practical was most useful for understanding business applications of AI?

# %% [markdown]
# # Submission
#
# Rename your notebook as:
#
# `Unsupervised_and_Reinforcement_Learning_Practical_Name.ipynb`
#
# Upload it to your GitHub repository under:
#
# `part-a/unsupervised-learning/`
#
# Also add one screenshot of the customer-segmentation graph.
